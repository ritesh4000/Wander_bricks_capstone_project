-- %%
use databricks_wanderbricks_dataset_dais_2025.wanderbricks;

select * 
from hosts 
limit 10;

describe hosts;

-- 1. Total count of hosts
select count(distinct host_id) as total_hosts 
from hosts;

-- 2. Country wise hosts
SELECT
    country,
    COUNT(DISTINCT host_id) AS total_hosts
FROM hosts
GROUP BY country
ORDER BY total_hosts DESC;


-- Top 10 countries by number of hosts

SELECT  country,
 COUNT(DISTINCT host_id) AS total_hosts
FROM hosts
GROUP BY country
ORDER BY total_hosts DESC
LIMIT 10; 
-- 3. Verified vs Not-verified

-- 4. Active vs non-active

-- 5. by host rating

-- 6. When did host joined the platform

-- 7.how many properties does each host manage.a
